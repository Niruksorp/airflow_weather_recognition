# %%
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 ImageDataGenerator
#       2 # Каталог с данными для обучения
#       3 train_dir = 'small/train'
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1. / 255,
                                  rotation_range=40,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  fill_mode='nearest')

# %%
image_file_name = r'C:\Users\gproskurin\Desktop\1.jpg'
img = tf.keras.preprocessing.image.load_img(image_file_name, target_size=(150, 150))
plt.imshow(img)

# %%
x = tf.keras.preprocessing.image.img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0
datagen = train_datagen.flow(x, batch_size=1)
for batch in train_datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(tf.keras.preprocessing.image.array_to_img(batch[0]))
    i += 1
    if i % 4 == 0:
        break
plt.show()
datagen.fit(image)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
